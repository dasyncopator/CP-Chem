# %%
import matplotlib.pyplot as plt
from obspy import read

# %%
filename = r"C:\Users\Tanay Mannikar\OneDrive - The University of Texas at Austin\CP Chem\CP Chem\miniseed data\00\2021-12-30 0024 00 GECKO.ms"
st = read(filename)
print(st[0].data)
plt.plot(st[0].data)
plt.show()
# Out:
# [-37 -15  14 ..., -13 -16 -24]
